# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install  tensorflow==2.2.0
# %load_ext tensorboard
# Out:
# ...
#      |████████████████████████████████| 516.2MB 34kB/s
# ...
#      |████████████████████████████████| 460kB 50.0MB/s
# ...
#      |████████████████████████████████| 3.0MB 39.6MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
import tensorflow as tf
# logdir='/content/drive/My Drive/Projectos/3D-PROTUCEL/Code/MU_Lux_CZ/lstm_tips_results_v07/logs/'
# tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %tensorboard --logdir '/content/drive/My Drive/Projectos/3D-PROTUCEL/Code/MU_Lux_CZ/mobilenet_lstm_external_onlydecoder_v05/logs/'
# %tensorboard --logdir '/content/drive/My Drive/Projectos/3D-PROTUCEL/Code/MU_Lux_CZ/mobilenet_lstm_external_onlydecoder_v05_keepfrombest/logs/'
# %tensorboard --logdir '/content/drive/My Drive/Projectos/3D-PROTUCEL/Code/MU_Lux_CZ/mobilenet_mobileunet_lstm_tips_large_pure_v01/logs/'
# Out:
# Reusing TensorBoard on port 6006 (pid 303), started 0:04:49 ago. (Use '!kill 303' to kill it.)

# %%
# %tensorboard --logdir '/content/drive/My Drive/Projectos/3D-PROTUCEL/Code/CellProtrusionTimeDLPhC/mobilenet_lstm_external_v05_keepfrombest/logs/'

# %%
# !kill 1263
